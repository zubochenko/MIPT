# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts
# %matplotlib inline

# %%
tex = sts.truncexpon(5)
ex = prs.rvs(1000)

# %%
x = np.linspace(0,10,100)
pdf = tex.pdf(x)
plt.plot(x, pdf, color = "red", label='pdf')
plt.hist(ex, density = True, color = "grey", label='histogram')
plt.legend()
plt.show()

# %%
tpl = (5, 10, 50)

for i in tpl:
    tpl_2 = []
    for _ in range(1000):
        tpl_2.append(tex.rvs(i).mean())
    plt.hist(tpl_2, 120, density=True, range=[0, 6], color = "grey", label='histogram')
    var = np.sqrt(1 / i)
    x = np.linspace(-1, 6, 100)
    norm = sts.norm.pdf(x , 1 , var)
    plt.plot(x, norm, color = "red", label='pdf')
    plt.legend()
    plt.title("Sample size %i" %i)
    plt.ylabel('f(x)')
    plt.xlabel('x')
    plt.show()

# %% [markdown]
# Центральная предельная теорема наглядно подтверждена
